# %% [markdown]
# ## Task: Sensor calibration
#
# **Basic Information:** Your development vehicle is equipped with a GPS platform and an optical speed sensor (OSS). The GPS is fused with an IMU and can therefore measure the speed in longitudinal and lateral direction. We assume in the following, that this sensor is mounted perfectly aligned with the vehicle longitudinal axis and therefore measures the speeds exactly despite sensor noise. Due to a fault during the construction of the mount, the optical speed sensor is slightly misaligned with the vehicle longitudinal axis and does not measure the correct speed. It is your task to calibrate the sensor with respect to the GPS orientation. The used coordinate frame is shown below. The longitudinal speed is called vx and the lateral speed vy and measured in mps.
#
# ![STM.PNG](attachment:STM.PNG)
#
# The dataset you obtain looks like this:
#
# ![VelCalibration.png](attachment:VelCalibration.png)
#
# **Question:** Your task is to write a python3 function which uses linear regression to calibrate the angular offset phi between the GPS and the OSS. The positive calibration angle is defined, such that the velocity vector of the OSS is rotated in counterclockwise direction and is fully aligned with the GPS velocity vector after calibration. The result is evaluated within a given tolerance band of 0.01 radian. Therefore you have to do the following steps:
#
# * Model the relation between the GPS measurements and the Optical speed measurements using the calibration angle phi. Use the standard rotation matrix which rotates in counterclockwise direction for positive angles.
# * You obtain two equations. One of them is more suitable for implementation. Think about which one it is and implement the better one. Apply the small angle assumption to achieve a representation which is linear in the parameters.
# * Implement the regression problem and solve it using the normal equation given in the lecture.
#
# *Hint: The data used here is not the same as in Moodle ;) *

# %%
# import necessary libraries. You do not need anything else! 
import numpy as np

# %%
# read data from csv 
data = np.genfromtxt('VelCalibrationRawData_StudentTest.csv', delimiter=',');
nPoints = 50; 
# map input data to meaningful variables, you can directly use this variables
vxGPS = np.reshape(data[:,0], (50,1));
vyGPS = np.reshape(data[:,1], (50,1));
vxOSS = np.reshape(data[:,2], (50,1));
vyOSS = np.reshape(data[:,3], (50,1));

# %%
# construct regression problem 
def calibrateOSS(vxGPS, vyGPS, vxOSS, vyOSS):
    # apply your solution here
    return phi

# %%
# target value check 
epsilon = 0.01; 
phiTrue = -0.068;
phiCalibrate = calibrateOSS(vxGPS, vyGPS, vxOSS, vyOSS); 
if(phiCalibrate<phiTrue+epsilon and phiCalibrate>phiTrue-epsilon): 
    print('True')
else:
    print('False')
